# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
airline_df = pd.read_csv('airline_dec_2008_50k.csv')
airline_df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           1  2008     12           1          1      NaN        1000
# 1           2  2008     12           1          1      NaN        1000
# 2           3  2008     12           1          1      NaN        1000
# 3           4  2008     12           1          1      NaN        1000
# 4           5  2008     12           1          1      NaN        1000
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0      NaN        1100            WN  ...     NaN     NaN          1
# 1      NaN        1110            US  ...     NaN     NaN          1
# 2      NaN        1125            MQ  ...     NaN     NaN          1
# 3      NaN        1227            EV  ...     NaN     NaN          1
# 4      NaN        1227            NW  ...     NaN     NaN          1
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
distance = airline_df['Distance']
distance.head()
# Out:
# 0    239
# 1    185
# 2    417
# 3    403
# 4    235
# Name: Distance, dtype: int64

# %%
mean_distance = distance.mean()
median_distance = distance.median()
skewness_distance =   distance.skew()
print("Mean Distance: ", mean_distance)
print("Median Distance: ", median_distance)
print("Skewness Distance: ", skewness_distance)
# Out:
# Mean Distance:  572.15812
# Median Distance:  446.0
# Skewness Distance:  1.912697191376648

# %%
plt.figure(figsize=(8,6))

sns.histplot(distance, kde = True, color='skyblue', bins = 30)

plt.axvline(mean_distance, color='red', linestyle='--', label = f'Mean : {mean_distance:.2f}')
plt.axvline(median_distance, color = 'black', linestyle = '--', label = f'Median: {median_distance:.2f}')

plt.title(f'Distribution of Distance\nSkewness: {skewness_distance:.2f}')
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.legend()
plt.tight_layout()
plt.show()

# %%
air_df=pd.read_csv("airline_passenger_satisfaction.csv")

# %%
air_df
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...

# %%
obs=air_df["On-board Service"]
obs.head()
# Out:
# 0    3
# 1    5
# 2    3
# 3    5
# 4    3
# Name: On-board Service, dtype: int64

# %%
md=obs.mean()
med=obs.median()
skd=obs.skew()
print("Mean:",md)
print("Median:",med)
print("Skewness:",skd)
# Out:
# Mean: 3.3830227902679395
# Median: 4.0
# Skewness: -0.4213196481539714

# %%
plt.figure(figsize=(8,6))

sns.histplot(obs, kde = True, color='skyblue', bins = 6)

plt.axvline(md, color='red', linestyle='--', label = f'Mean_OBS : {md:.2f}')
plt.axvline(med, color = 'black', linestyle = '--', label = f'Median_OBS: {med:.2f}')

plt.title(f'Distribution of On Board Servivce Ratings\nSkewness: {skd:.2f}')
plt.xlabel("Ratings")
plt.ylabel("Frequency")
plt.legend()
plt.tight_layout()  
plt.show()
