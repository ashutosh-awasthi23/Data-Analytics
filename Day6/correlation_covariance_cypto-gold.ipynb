# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("SP500 oil gold bitcoin.csv")
corr1=df[["BITCOIN","Gold","S&P500"]].corr()
print(corr1)
cov1=df[["BITCOIN","Gold","S&P500"]].cov()
print(cov1)
# Out:
#           BITCOIN      Gold    S&P500
# BITCOIN  1.000000  0.594622  0.862225
# Gold     0.594622  1.000000  0.445658
# S&P500   0.862225  0.445658  1.000000
#               BITCOIN          Gold        S&P500
# BITCOIN  2.134886e+08  2.124359e+06  1.187061e+07
# Gold     2.124359e+06  5.978601e+04  1.026755e+05
# S&P500   1.187061e+07  1.026755e+05  8.878310e+05

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 6))
axes[0].scatter(df["BITCOIN"],df["Gold"])
axes[1].scatter(df["BITCOIN"],df["S&P500"])

xmin,xmax=plt.xlim()
ymin,ymax=plt.ylim()

text_x=xmin+0.7*(xmax-xmin)
text_y=ymin+0.3*(ymax-ymin)


# axes[0].text(text_x, text_y,f"Correlation:{corr1.loc['BITCOIN','Gold']:.2f}",ha="center",va="center",fontsize=12)
# axes[1].text(text_x, text_y,f"Correlation:{corr1.loc['BITCOIN','S&P500']:.2f}",ha="center",va="center",fontsize=12)


# plt.text(text_x, text_y,f"Correlation:{corr1.loc['BITCOIN','Gold']:.2f}",ha="center",va="center",fontsize=12)
# plt.text(text_x, text_y,f"Correlation:{corr1.loc['BITCOIN','S&P500']:.2f}",ha="center",va="center",fontsize=12)

plt.show()
